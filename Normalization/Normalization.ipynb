# %% [markdown]
# # Normalization

# %% [markdown]
# ### What is Normalization?
# - Normalization in Deep Learning means scaling input data (or intermediate activations) into a standard range so that learning is more stable, faster, and effective.
# - 👉 Why? Because neural networks are sensitive to the scale of inputs — if one feature has values in the thousands and another between 0–1, the optimization process gets unbalanced.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# | Type                   | Normalizes Over | Best Used In         |
# | ---------------------- | --------------- | -------------------- |
# | Input Normalization    | Raw features    | Preprocessing        |
# | Batch Normalization    | Mini-batch      | CNNs, MLPs           |
# | Layer Normalization    | Features        | RNNs, Transformers   |
# | Instance Normalization | Each instance   | Style transfer, GANs |
# | Group Normalization    | Channel groups  | Small batch CNNs     |
# | Weight Normalization   | Weight vectors  | Faster optimization  |
