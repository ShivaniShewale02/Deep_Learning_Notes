# %% [markdown]
# ### Gradient Descent

# %% [markdown]
# Gradient Descent is an optimization algorithm used to minimize a loss function (cost function) by iteratively updating model parameters (weights & biases).
#
# It’s like finding the lowest point in a valley by taking steps downhill.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
