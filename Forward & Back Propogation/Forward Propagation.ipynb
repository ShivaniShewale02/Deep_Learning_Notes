# %% [markdown]
# # Forward Propagation

# %% [markdown]
# ### What is Forward Propagation?
# Forward Propagation is the process of passing input data through a neural network layer by layer until an output is produced.
#
# It involves linear transformation + non-linear activation at each layer.
# Mathematically, for each neuron:
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# . -- is because we get the result in matrix format so we use . product for it.
# w & b-- (default decided as 1) we initially add some random value and then it automatically gets changed accordingly to get better results. ( there are techniques for to get the value of weight)
#
# Note: we minimize the value of loss means the difference between y defined and y predicted which we do with the help of gradient desent and we do it by updating the value of w & b using backpropagation.

# %% [markdown]
# ### Steps in Forward Propagation
#
# ##### 1. Input Layer
# - Take raw input features (e.g., pixels in an image, numbers in a dataset).
# - Example:
#   **x** = [x₁, x₂, ..., xₙ]
#
#
# ##### 2. Hidden Layers
# For each hidden layer neuron:
# ![image.png](attachment:image.png)
#
# ##### 3. Output Layer
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Forward Propagation Summary
# ![image.png](attachment:image.png)
