# %% [markdown]
# # Loss Function

# %% [markdown]
# ### What is a Loss Function?
# A Loss Function (also called Cost Function or Error Function) measures how well a neural network’s predictions match the actual target values.
# A Loss Function (also called Cost Function or Error Function) is a mathematical function that measures the difference between the predicted output of the neural network and the actual target (ground truth).
#
# 👉 It tells us how wrong the model is.
# 👉 During training, the optimizer (e.g., Gradient Descent) tries to minimize the loss function by adjusting weights.
# 👉 The goal of training is to minimize the loss function using optimization algorithms like Gradient Descent.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Why is it Important?
# - Without a loss function, the model would not know how to update weights.
# - The loss function provides a signal for backpropagation (via gradients).
# - Different tasks require different loss functions.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Types of Loss Functions

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### NOTE:
# ##### Regression Loss Functions
# 1) When we have outliers in the data then we do not use **Mean Square Error**.
# 2) Alternative of mean square error when data have outliers then we will user **Mean Square Error**. It is not defrentiable so we can not directly use the gradient decent algorithm.
# 3) If the data have more than 30% are outliers then we use **Huber Loss** as it works in tow way based on the hyperparameters based loss value.
#
# ##### Classification Loss Function
# 1) We use **Log Loss** when the output of data is in the form of binary(0, 1) so we use this loss function.
# 2) When the results are in more than 2 types and less than 4 then we use **Categorical Cross Entropy**. It do one hot encoding and provide the result.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
