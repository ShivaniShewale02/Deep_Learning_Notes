# %% [markdown]
# # Learning Rate

# %% [markdown]
# - While optimizing the weight we use the formula of gradient decent:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - The n value there is learning rate which helps in modifing the value of Weight.
# - Its basically tell how quickly we takes the steps while backpropogating to change the value of weight.

# %% [markdown]
# ### Ways to Optimize the Learning Rate.
#
# 1. Try lots of differnt learning rates and see what works "just right".
# 2. Do something smarter! Design an adaptive learning rate that "adapts" to the landscape.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
