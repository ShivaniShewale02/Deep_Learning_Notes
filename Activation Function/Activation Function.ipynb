# %% [markdown]
# # Activation Function

# %% [markdown]
# ### What is an Activation Function?
# An activation function is a mathematical function applied to the output of a neuron (weighted sum + bias) to decide whether the neuron should "activate" (fire) or not.
#
# It introduces non-linearity into the neural network, allowing it to learn complex patterns beyond simple linear relationships.
#
# 👉 Without activation functions, an Artificial Neural Network (ANN) is just a linear regression model (no matter how many layers it has).
#
# An Activation function decides whether a neuron should be activated or not. This means that it will decide weather the neurons input to the neteork is important or not in the process of prediction using simpler mathematical operations.

# %% [markdown]
# ### 🔹 The Role of Activation Functions
# - Non-linearity – Helps networks learn from complex data (images, speech, etc.).
# - Decision-making – Determines which neurons should be active.
# - Gradient Flow – Affects training via backpropagation (derivatives).
# - Output Control – Restricts values (e.g., between 0–1 for probability).

# %% [markdown]
# ## Types of Activation Functions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Summary Table
#
# | Activation Function | Range        | Pros              | Cons               | Use Case                       |
# | ------------------- | ------------ | ----------------- | ------------------ | ------------------------------ |
# | Linear              | (-∞, ∞)      | Simple            | No non-linearity   | Regression                     |
# | Step                | {0,1}        | Simple logic      | Not differentiable | Old perceptrons                |
# | Sigmoid             | (0,1)        | Probabilities     | Vanishing gradient | Binary classification          |
# | Tanh                | (-1,1)       | Zero-centered     | Vanishing gradient | Hidden layers                  |
# | ReLU                | \[0, ∞)      | Fast, widely used | Dying neurons      | CNNs, DNNs                     |
# | Leaky ReLU          | (-∞, ∞)      | Fixes dying ReLU  | Hyperparameter (α) | Improved CNNs                  |
# | Softmax             | (0,1), sum=1 | Multi-class probs | Expensive          | Output layer in classification |

# %% [markdown]
# Hidden layers → ReLU (default), Leaky ReLU/ELU/Swish (if better stability).
#
# Output layer (binary classification) → Sigmoid.
#
# Output layer (multi-class classification) → Softmax.
#
# Regression output → Linear (no activation).
