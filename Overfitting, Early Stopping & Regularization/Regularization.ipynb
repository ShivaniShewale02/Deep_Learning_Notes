# %% [markdown]
# # Regularization

# %% [markdown]
# ### What is Regularization?
# - Regularization refers to techniques used to constrain or penalize the complexity of a neural network, so it doesn’t just memorize the training data (overfitting), but learns general patterns that work well on unseen data.
# - 👉 In short: Regularization makes models simpler, more robust, and better at generalization.

# %% [markdown]
# ### Why Do We Need Regularization?
# - Deep learning models often have millions of parameters.
# - They can easily memorize training data, leading to high training accuracy but poor test accuracy.
# - Regularization adds constraints or noise to reduce variance.

# %% [markdown]
# ### Type Of Regularization in Deep Learning

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# | Regularization Technique | How It Works                         | Best For                   |
# | ------------------------ | ------------------------------------ | -------------------------- |
# | L1 Regularization        | Penalizes sum of                     | w  → sparsity  Feature selection |
# | L2 Regularization        | Penalizes sum of w² → small weights  | Most models (weight decay) |
# | Dropout                  | Randomly drop neurons                | Large networks             |
# | Data Augmentation        | Generate diverse data                | Image, text, audio         |
# | Early Stopping           | Halt when val\_loss ↑                | All tasks                  |
# | Batch Normalization      | Normalize layer inputs               | CNNs, deep MLPs            |
# | Noise Injection          | Add noise to inputs/weights          | Autoencoders, NLP          |
# | Label Smoothing          | Soft targets instead of hard one-hot | Classification             |
